# %% [markdown]
# # Backup Covering Location Problem (BCLP)

# %% [markdown]
# #### Import the required modules

# %%
import warnings
warnings.filterwarnings('ignore')
import geopandas
import matplotlib.pyplot as plt
import pulp
from allagash import Coverage, Problem
# %matplotlib inline

# %% [markdown]
# #### Load the data

# %%
d = geopandas.read_file("sample_data/demand_point.shp")
s = geopandas.read_file("sample_data/facility_service_areas.shp")
s2 = geopandas.read_file("sample_data/facility2_service_areas.shp")

# %% [markdown]
# #### Plot the data

# %%
fig, ax = plt.subplots(figsize=(15, 15))
ax.set_aspect('equal')
d.plot(ax=ax, color='blue')
s.plot(ax=ax, color='yellow', alpha=0.3)
s2.plot(ax=ax, color='green', alpha=0.3);

# %% [markdown]
# #### Create the coverage

# %%
coverage1 = Coverage.from_geodataframes(d, s, "GEOID10", "ORIG_ID", demand_col="Population", demand_name="demand", supply_name="supply1")
coverage2 = Coverage.from_geodataframes(d, s2, "GEOID10", "ORIG_ID", demand_col="Population", demand_name="demand", supply_name="supply2")

# %% [markdown]
# #### Create the problem

# %%
problem = Problem.bclp([coverage1, coverage2], max_supply={coverage1: 5, coverage2: 19})

# %% [markdown]
# #### Solve the problem

# %%
problem.solve(pulp.GLPK(msg=False));

# %% [markdown]
# #### Plot the selected locations

# %%
selected_locations = s.query(f"ORIG_ID in ({','.join(problem.selected_supply(coverage1))})")
selected_locations2 = s2.query(f"ORIG_ID in ({','.join(problem.selected_supply(coverage2))})")

fig, ax = plt.subplots(figsize=(15, 15))
ax.set_aspect('equal')
d.plot(ax=ax, color='blue')
selected_locations.plot(ax=ax, color='yellow', alpha=0.3)
selected_locations2.plot(ax=ax, color='green', alpha=0.3);

# %% [markdown]
# #### Find the total demand that is covered

# %%
covered_demand = d.query(f"GEOID10 in ({[f'{i}' for i in problem.selected_demand(coverage1)]})")
print(f'{(covered_demand["Population"].sum() / d["Population"].sum()*100):0.2f}%')
# Out:
# 100.00%

# %% [markdown]
# #### Find the demand that is provided backup coverage

# %%
print(f'{(problem.pulp_problem.objective.value() / d["Population"].sum()*100):0.2f}%')
# Out:
# 55.44%

# %% [markdown]
# #### Find total number of facilities

# %%
print(len(selected_locations) + len(selected_locations2))
# Out:
# 24
